# %%
import os

extentions = []
path = "C:/Users/pkmpp/Downloads"
for file in os.listdir(path):
    extention = file.split(".")[1]
    if extention not in extentions:
        extentions.append(extention)

print(extentions)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3960\4100269465.py in <cell line: 0>()
#       4 path = "C:/Users/pkmpp/Downloads"
#       5 for file in os.listdir(path):
# ----> 6     extention = file.split(".")[1]
#       7     if extention not in extentions:
#       8         extentions.append(extention)
#
# IndexError: list index out of range

# %%
import os

extentions = []
filePath = "C:/Users/pkmpp/Downloads"
for file in os.listdir(filePath):
    file_name,extention = os.path.splitext(file)
    if extention not in extentions:
        extentions.append(extention)

print(extentions)
# Out:
# ['.csv', '.jpg', '.eps', '.svg', '.zip', '.exe', '.pdf', '.ini', '.wav', '.mp4', '.json', '.ipynb', '.gguf', '.png', '.ppt', '', '.crdownload']

# %%
from pathlib import Path
p = Path('.')
for x in p.iterdir():
    print(x)
# Out:
# .config
# sample_data

# %%
extentions = ["apple"]
new = "apple"
if new not in extentions:
    print("not in")
else:
    print("has it")
    # extentions.append(new)
# Out:
# has it

# %%
extentions

# %%
def main():
    print("hello")

main()
# Out:
# hello
